# %%
import pandas as pd

# %%
bracero_df_og = pd.read_csv('../data/original/bracero_aer_dataset.tab', sep='\t')

# %%
bracero_df_og.sample(10)
# Out:
#       State  State_FIPS  Region  Year  Month  DailywoBoard_final  \
# 5048     LA          22     7.0  1970    1.0                10.1
# 14497    VA          51     5.0  1966    7.0                 7.8
# 13935    VT          50     1.0  1944    6.0                 NaN
# 7988     NE          31     4.0  1965   11.0                 NaN
# 13527    TX          48     7.0  1974    7.0                16.0
# 12855    SD          46     4.0  1962   10.0                 9.1
# 11034    OK          40     7.0  1957   10.0                 7.3
# 9301     NM          35     8.0  1957    1.0                 6.2
# 7197     MS          28     6.0  1945   12.0                 NaN
# 1510     CO           8     8.0  1961   11.0                 NaN
#
#        HourlyComposite_final  MonthlyComposite_final  \
# 5048                   1.250                     NaN
# 14497                  0.837                     NaN
# 13935                    NaN                     NaN
# ...

# %%
bracero_df_og.columns
# Out:
# Index(['State', 'State_FIPS', 'Region', 'Year', 'Month', 'DailywoBoard_final',
#        'HourlyComposite_final', 'MonthlyComposite_final',
#        'TotalHiredSeasonal_final', 'Mexican_final',
#        'HiredWorkersonFarms_final', 'Local_final', 'Intrastate_final',
#        'Interstate_final', 'TotalForeign_final', 'Jamaican_final',
#        'Bahamian_final', 'BWIOthers_final', 'BWI_final', 'Canadian_final',
#        'CanadianOthers_final', 'PuertoRican_final', 'OtherForeign_final',
#        'TotalAg_final', 'Nonlocal_final', 'Farmworkers_Total',
#        'Farmworkers_Family', 'Farmworkers_Hired', 'Petroleum', 'Tractors',
#        'Cotton_machine', 'Sugarbeet_machine', 'Sugarbeet_monogerm',
#        'SugarBeets', 'Cotton', 'Tomatoes_total', 'Lettuce',
#        'Strawberries_total', 'Citrus', 'Cantaloupes', 'BrusselsSprouts',
#        'Asparagus_total', 'Celery', 'Cucumbers_pickle', 'Tomatoes_fresh',
#        'Tomatoes_proc', 'Strawberries_fresh', 'Strawberries_proc',
# ...

# %%
farmworkers_df = bracero_df_og[['State','Year','Month', 'Region', 'TotalHiredSeasonal_final','Mexican_final','HiredWorkersonFarms_final',
              'Local_final','Intrastate_final','Interstate_final','TotalForeign_final','Jamaican_final','Bahamian_final',
              'BWIOthers_final','BWI_final','Canadian_final','CanadianOthers_final','PuertoRican_final', 'TotalAg_final','Nonlocal_final','Farmworkers_Total','Farmworkers_Family','Farmworkers_Hired']]

# %%
farmworkers_df.sample(10)
# Out:
#       State  Year  Month  Region  TotalHiredSeasonal_final  Mexican_final  \
# 6058     MA  1965   12.0     1.0                    1105.0            0.0
# 2112     DE  1954    4.0     5.0                       NaN            NaN
# 8060     NE  1965    5.0     4.0                       NaN            NaN
# 9454     NM  1956    8.0     8.0                    5579.0         3858.0
# 4125     IA  1956    9.0     4.0                     721.0           21.0
# 7148     MS  1973    6.0     6.0                       NaN            NaN
# 3585     IL  1967   11.0     NaN                       NaN            NaN
# 15151    WV  1947   10.0     5.0                       NaN            NaN
# 11234    OK  1944    9.0     7.0                       NaN            NaN
# 6014     MA  1944    6.0     1.0                       NaN            NaN
#
#        HiredWorkersonFarms_final  Local_final  Intrastate_final  \
# 6058                         NaN       1089.0               0.0
# ...

# %%
farmworkers_df = farmworkers_df.rename(columns={'TotalHiredSeasonal_final': 'TotalHiredSeasonal', 
                                               'Mexican_final': 'Mexican', 'HiredWorkersonFarms_final': 'HiredWorkers',
                                               'Local_final': 'Local', 'Intrastate_final': 'Intrastate', 'Interstate_final': 'Interstate',
                                               'TotalForeign_final': 'TotalForeign', 'Jamaican_final': 'Jamaican', 'Bahamian_final': 'Bahamian',
                                               'BWIOthers_final': 'BWIOthers', 'BWI_final': 'BWI', 'Canadian_final': 'Canadian', 'CanadianOthers_final': 'CanaidanOthers',
                                               'PuertoRican_final': 'PuertoRican', 'OtherForeign_final': 'OtherForeign', 'TotalAg_final': 'TotalAgWorkers',
                                               'Nonlocal_final': 'Nonlocal'})

# %%
farmworkers_df.sample(10)
# Out:
#       State  Year  Month  Region  TotalHiredSeasonal  Mexican  HiredWorkers  \
# 8054     NE  1945    5.0     4.0                 NaN    737.0           NaN
# 4893     KY  1955    4.0     6.0                 NaN      NaN      152000.0
# 11816    PA  1971    3.0     2.0              2684.0      NaN           NaN
# 12910    TN  1955    1.0     6.0                 NaN      NaN       96000.0
# 4804     KY  1966   11.0     6.0                 NaN      NaN           NaN
# 8104     NE  1943   10.0     4.0                 NaN    180.0      324000.0
# 681      AZ  1965   11.0     8.0             21097.0      0.0           NaN
# 2142     DE  1960    4.0     5.0                 NaN      NaN      250000.0
# 12310    SC  1969    9.0     5.0             12025.0      NaN           NaN
# 13200    TN  1960    9.0     6.0             28706.0      0.0           NaN
#
#          Local  Intrastate  Interstate  ...  BWIOthers  BWI  Canadian  \
# ...

# %%
farmworkers_df.to_csv('farmworkers.csv', encoding='utf-8', index=False)

# %%
farmworkers_df.groupby('State').sum()
# Out:
#          Year   Month  Region  TotalHiredSeasonal    Mexican  HiredWorkers  \
# State
# AL     636761  2105.0  1818.0           1442463.0        0.0    28193000.0
# AR     669949  2229.0  2240.0           3906625.0   680217.0    39344000.0
# AZ     710894  2387.0  2728.0           3504553.0   991847.0    15585900.0
# CA     726482  2419.0  3141.0          26194997.0  6309812.0    35237000.0
# CO     640660  2110.0  2440.0           1494793.0   200751.0    15585900.0
# CT     636761  2105.0   303.0           1032350.0        0.0     7235300.0
# DE     636761  2105.0  1515.0            328358.0      230.0    45822000.0
# FL     636761  2105.0  1515.0           8368949.0        0.0    45822000.0
# GA     636761  2105.0  1515.0           2602010.0    12069.0    45822000.0
# IA     636761  2105.0  1212.0            680187.0     9221.0    25163000.0
# ID     636761  2105.0  2424.0           1336185.0    83111.0    15585900.0
# ...

# %%
farmworkers_df.groupby('Year').sum()
# Out:
#                                                   State   Month  Region  \
# Year
# 1942  ALALALALAZAZAZAZARARARARCACACACACOCOCOCOCTCTCT...  1056.0   952.0
# 1943  ALALALALALALALALALALAZAZAZAZAZAZAZAZAZAZARARAR...  3504.0  2380.0
# 1944  ALALALALALALALALALALALALAZAZAZAZAZAZAZAZAZAZAZ...  3744.0  2856.0
# 1945  ALALALALALALALALALALALALAZAZAZAZAZAZAZAZAZAZAZ...  3744.0  2856.0
# 1946  ALALALALALALALALALALALALAZAZAZAZAZAZAZAZAZAZAZ...  3744.0  2856.0
# 1947  ALALALALALALALALALALALALAZAZAZAZAZAZAZAZAZAZAZ...  3744.0  2856.0
# 1948  ALALALALAZAZAZAZAZAZAZAZARARARARCACACACACACACA...  1220.0  1113.0
# 1949  ALALALALAZAZAZAZAZAZAZAZARARARARCACACACACACACA...  1288.0  1129.0
# 1950  ALALALALAZAZAZAZAZAZAZAZAZAZAZAZARARARARCACACA...  1325.0  1191.0
# 1951  ALALALALAZAZAZAZAZAZAZAZAZAZAZAZARARARARARARAR...  1344.0  1228.0
# 1952  ALALALALAZAZAZAZAZAZAZAZAZAZAZAZARARARARARARAR...  1401.0  1254.0
# 1953  ALALALALALALALALALAZAZAZAZAZAZAZAZAZAZAZAZARAR...  3062.0  2291.0
# ...

# %%
co_filter = farmworkers_df['State'] == 'CO'

# %%
co_farmworkers = farmworkers_df[co_filter]

# %%
co_farmworkers.sample(10)
# Out:
#      State  Year  Month  Region  TotalHiredSeasonal  Mexican  HiredWorkers  \
# 1722    CO  1958   10.0     8.0             19716.0    151.0      191000.0
# 1469    CO  1951    4.0     8.0                 NaN      NaN       63000.0
# 1726    CO  1966    4.0     8.0                 NaN      NaN       67000.0
# 1409    CO  1967   11.0     NaN                 NaN      NaN           NaN
# 1515    CO  1963    7.0     8.0             13662.0   2597.0      167000.0
# 1430    CO  1963   11.0     8.0              1502.0      4.0           NaN
# 1530    CO  1955    7.0     8.0             16378.0    997.0      172000.0
# 1597    CO  1967    6.0     8.0             13024.0      NaN           NaN
# 1489    CO  1967   10.0     8.0              8427.0      NaN      126000.0
# 1644    CO  1946    2.0     8.0                 NaN     46.0           NaN
#
#        Local  Intrastate  Interstate  ...  BWIOthers  BWI  Canadian  \
# 1722  9195.0      1868.0      3771.0  ...        0.0  NaN       NaN
# ...

# %%
co_farmworkers['Region'] == 2.0
# Out:
# 1401    False
# 1402    False
# 1403    False
# 1404    False
# 1405    False
#         ...
# 1723    False
# 1724    False
# 1725    False
# 1726    False
# 1727    False
# Name: Region, Length: 327, dtype: bool

# %%
farmworkers_condensed = farmworkers_df[['State','Year','Month', 'Region', 'TotalHiredSeasonal','Mexican','HiredWorkers',
              'Local','Intrastate','Interstate','TotalForeign','TotalAgWorkers','Nonlocal','Farmworkers_Total',
                                        'Farmworkers_Family','Farmworkers_Hired']]

# %%
farmworkers_condensed.head(10)
# Out:
#   State  Year  Month  Region  TotalHiredSeasonal  Mexican  HiredWorkers  \
# 0    AL  1947    7.0     6.0                 NaN      NaN      207000.0
# 1    AL  1963    9.0     6.0             21980.0      0.0           NaN
# 2    AL  1945    8.0     6.0                 NaN      NaN           NaN
# 3    AL  1972    4.0     6.0                 NaN      NaN       81000.0
# 4    AL  1964   10.0     6.0             16195.0      0.0      295000.0
# 5    AL  1946    3.0     6.0                 NaN      NaN           NaN
# 6    AL  1956    4.0     6.0                 NaN      NaN      147000.0
# 7    AL  1961   10.0     6.0             24335.0      0.0      405000.0
# 8    AL  1965    5.0     6.0              5930.0      0.0           NaN
# 9    AL  1945    7.0     6.0                 NaN      NaN      215000.0
#
#      Local  Intrastate  Interstate  TotalForeign  TotalAgWorkers  Nonlocal  \
# 0      NaN         NaN         NaN           NaN             NaN       NaN
# ...

# %%
farmworkers_condensed.sample(10)
# Out:
#       State  Year  Month  Region  TotalHiredSeasonal  Mexican  HiredWorkers  \
# 13473    TX  1972    5.0     7.0                 NaN      NaN           NaN
# 5028     LA  1965   12.0     7.0              8525.0      0.0           NaN
# 14228    VA  1944    4.0     5.0                 NaN      NaN      366000.0
# 10973    OK  1969   12.0     7.0              7870.0      NaN           NaN
# 14838    WA  1965   11.0     9.0              4030.0      0.0           NaN
# 9607     NM  1944   10.0     8.0                 NaN      NaN      158000.0
# 6499     MI  1971    4.0     3.0                 NaN      NaN       68000.0
# 3089     ID  1946    6.0     8.0                 NaN   2202.0           NaN
# 2080     DE  1969    8.0     5.0                 NaN      NaN           NaN
# 11746    PA  1957    1.0     2.0                 NaN      NaN       95000.0
#
#          Local  Intrastate  Interstate  TotalForeign  TotalAgWorkers  \
# ...

# %%
co_filter = farmworkers_condensed['State'] == 'CO'
co_farmworkers = farmworkers_condensed[co_filter]
co_farmworkers.sample(10)
# Out:
#      State  Year  Month  Region  TotalHiredSeasonal  Mexican  HiredWorkers  \
# 1471    CO  1943    9.0     8.0                 NaN    705.0           NaN
# 1459    CO  1971    7.0     8.0                 NaN      NaN      133000.0
# 1716    CO  1947    6.0     8.0                 NaN    595.0           NaN
# 1694    CO  1956    9.0     8.0             19354.0   1566.0           NaN
# 1515    CO  1963    7.0     8.0             13662.0   2597.0      167000.0
# 1670    CO  1966    1.0     8.0                 NaN      NaN       62000.0
# 1607    CO  1964    8.0     8.0             13903.0   3545.0           NaN
# 1561    CO  1971    1.0     8.0                 NaN      NaN       60900.0
# 1502    CO  1948    4.0     8.0                 NaN      NaN      109000.0
# 1655    CO  1950    4.0     8.0                 NaN    812.0       63000.0
#
#        Local  Intrastate  Interstate  TotalForeign  TotalAgWorkers  Nonlocal  \
# ...

# %%
al_filter = farmworkers_condensed['State'] == 'AL'
al_farmworkers = farmworkers_condensed[al_filter]
al_farmworkers.sample(10)
# Out:
#     State  Year  Month  Region  TotalHiredSeasonal  Mexican  HiredWorkers  \
# 310    AL  1970    6.0     6.0             10640.0      NaN           NaN
# 270    AL  1953   10.0     6.0                 NaN      NaN      454000.0
# 122    AL  1972    6.0     6.0                 NaN      NaN           NaN
# 191    AL  1944    1.0     6.0                 NaN      NaN      130000.0
# 222    AL  1968    6.0     6.0                 NaN      NaN           NaN
# 213    AL  1959    1.0     6.0                 NaN      NaN       63000.0
# 219    AL  1949   10.0     6.0                 NaN      NaN      584000.0
# 167    AL  1959    8.0     6.0              3690.0      0.0           NaN
# 218    AL  1962    4.0     6.0                 NaN      NaN      127000.0
# 243    AL  1947   12.0     6.0                 NaN      NaN           NaN
#
#        Local  Intrastate  Interstate  TotalForeign  TotalAgWorkers  Nonlocal  \
# ...

# %%
co_farmworkers.value_counts('Region')
# Out:
# Region
# 8.0    305
# Name: count, dtype: int64

# %%
farmworkers_condensed.value_counts('State')
# Out:
# State
# CA    371
# AZ    363
# MD    354
# MI    353
# VA    346
# AR    342
# NY    336
# OR    334
# IN    333
# LA    331
# NJ    331
# WA    330
# NM    329
# CO    327
# MN    326
# OK    325
# OH    325
# NV    325
# PA    325
# AL    325
# RI    325
# SC    325
# TN    325
# TX    325
# UT    325
# VT    325
# WI    325
# WV    325
# SD    325
# NC    325
# NH    325
# NE    325
# CT    325
# DE    325
# FL    325
# GA    325
# IA    325
# ID    325
# IL    325
# KS    325
# KY    325
# MA    325
# ME    325
# MO    325
# MS    325
# MT    325
# ND    325
# WY    325
# Name: count, dtype: int64

# %%
co_farmworkers['Region'].isna().value_counts()
# Out:
# Region
# False    305
# True      22
# Name: count, dtype: int64

# %%
farmworkers_condensed['State'].isna().value_counts()
# Out:
# State
# False    15831
# Name: count, dtype: int64

# %%
farmworkers_condensed[farmworkers_condensed.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [State, Year, Month, Region, TotalHiredSeasonal, Mexican, HiredWorkers, Local, Intrastate, Interstate, TotalForeign, TotalAgWorkers, Nonlocal, Farmworkers_Total, Farmworkers_Family, Farmworkers_Hired]
# Index: []

# %%
year_filter = co_farmworkers['Year'] == 1958
co_farmworkers[year_filter].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12 entries, 1403 to 1722
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   State               12 non-null     object
#  1   Year                12 non-null     int64
#  2   Month               12 non-null     float64
#  3   Region              10 non-null     float64
#  4   TotalHiredSeasonal  7 non-null      float64
#  5   Mexican             7 non-null      float64
#  6   HiredWorkers        4 non-null      float64
#  7   Local               7 non-null      float64
#  8   Intrastate          7 non-null      float64
#  9   Interstate          7 non-null      float64
#  10  TotalForeign        7 non-null      float64
#  11  TotalAgWorkers      7 non-null      float64
#  12  Nonlocal            0 non-null      float64
#  13  Farmworkers_Total   12 non-null     float64
#  14  Farmworkers_Family  12 non-null     float64
# ...

# %%
ca_filter = farmworkers_condensed['State'] == 'CA'
ca_farmworkers = farmworkers_condensed[ca_filter]
year_filter = ca_farmworkers['Year'] == 1957
ca_farmworkers[year_filter].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, 1080 to 1353
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   State               10 non-null     object
#  1   Year                10 non-null     int64
#  2   Month               10 non-null     float64
#  3   Region              9 non-null      float64
#  4   TotalHiredSeasonal  8 non-null      float64
#  5   Mexican             8 non-null      float64
#  6   HiredWorkers        4 non-null      float64
#  7   Local               8 non-null      float64
#  8   Intrastate          8 non-null      float64
#  9   Interstate          8 non-null      float64
#  10  TotalForeign        8 non-null      float64
#  11  TotalAgWorkers      8 non-null      float64
#  12  Nonlocal            0 non-null      float64
#  13  Farmworkers_Total   5 non-null      float64
#  14  Farmworkers_Family  5 non-null      float64
# ...

# %%
year_filter = al_farmworkers['Year'] == 1957
al_farmworkers[year_filter].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, 20 to 231
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   State               10 non-null     object
#  1   Year                10 non-null     int64
#  2   Month               10 non-null     float64
#  3   Region              9 non-null      float64
#  4   TotalHiredSeasonal  7 non-null      float64
#  5   Mexican             7 non-null      float64
#  6   HiredWorkers        4 non-null      float64
#  7   Local               7 non-null      float64
#  8   Intrastate          7 non-null      float64
#  9   Interstate          7 non-null      float64
#  10  TotalForeign        7 non-null      float64
#  11  TotalAgWorkers      7 non-null      float64
#  12  Nonlocal            0 non-null      float64
#  13  Farmworkers_Total   5 non-null      float64
#  14  Farmworkers_Family  5 non-null      float64
# ...

# %%
year_filter = co_farmworkers['Year'] == 1954
co_farmworkers[year_filter]
# Out:
#      State  Year  Month  Region  TotalHiredSeasonal  Mexican  HiredWorkers  \
# 1436    CO  1954    4.0     8.0                 NaN      NaN       71000.0
# 1537    CO  1954    5.0     8.0              8016.0      0.0           NaN
# 1587    CO  1954    8.0     8.0             19202.0    306.0           NaN
# 1599    CO  1954   10.0     8.0             16956.0    107.0      199000.0
# 1674    CO  1954    7.0     8.0             15471.0    536.0      176000.0
# 1681    CO  1954    1.0     8.0                 NaN      NaN       93000.0
# 1701    CO  1954    9.0     8.0             21817.0    437.0           NaN
# 1704    CO  1954   11.0     8.0                 NaN      NaN           NaN
# 1706    CO  1954    6.0     8.0             16014.0   1910.0           NaN
#
#         Local  Intrastate  Interstate  TotalForeign  TotalAgWorkers  Nonlocal  \
# 1436      NaN         NaN         NaN           NaN             NaN       NaN
# ...

# %%
year_filter = ca_farmworkers['Year'] == 1954
ca_farmworkers[year_filter]
# Out:
#      State  Year  Month  Region  TotalHiredSeasonal  Mexican  HiredWorkers  \
# 1061    CA  1954    2.0     9.0                 NaN  16500.0           NaN
# 1094    CA  1954   12.0     9.0                 NaN  29000.0           NaN
# 1206    CA  1954    6.0     9.0            192410.0  29110.0           NaN
# 1213    CA  1954    3.0     9.0                 NaN  14300.0           NaN
# 1224    CA  1954   10.0     9.0            241800.0  50770.0      464000.0
# 1229    CA  1954    7.0     9.0            187800.0  29800.0      378000.0
# 1250    CA  1954    4.0     9.0                 NaN  18200.0      183000.0
# 1267    CA  1954    5.0     9.0            172250.0  27100.0           NaN
# 1268    CA  1954    9.0     9.0            235400.0  47130.0           NaN
# 1317    CA  1954    1.0     9.0                 NaN  14300.0      183000.0
# 1320    CA  1954   11.0     9.0            183700.0  35120.0           NaN
# ...
